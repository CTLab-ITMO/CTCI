# %% [markdown]
# # YOLOv8 for bubbles detection

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data="C:\Internship\ITMO_ML\CTCI\data\yolo_dataset\mid_bubbles_69\data.yaml" \
epochs=80 \
imgsz=800
# Out:
# New https://pypi.org/project/ultralytics/8.1.9 available рџ�ѓ Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.228 рџљЂ Python-3.10.0 torch-2.1.2+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 16380MiB)
# ...
