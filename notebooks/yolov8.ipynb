# %% [markdown]
# # YOLOv8 for bubbles detection

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data=r"C:\Internship\ITMO ML\CTCI\data\yolo_dataset\bubbles_0\data.yaml" \
epochs=20 \
imgsz=640
# Out:
# ...
# Ultralytics YOLOv8.0.228 рџљЂ Python-3.10.0 torch-2.1.2+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
# ...
